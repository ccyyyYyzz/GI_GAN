# %% [markdown]
# # NS-MC-GAN Colab Runner
#
# Use this notebook to run extra Phase 10/11 jobs on Colab. Do not duplicate the local Windows `hadamard10_full_noise001` run.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Upload or clone the repository so it is located at `/content/ns_mc_gan_gi`, then run setup.

# %%
# %cd /content/ns_mc_gan_gi
# !bash scripts/colab_setup.sh

# %% [markdown]
# Recommended first job: 5% Hadamard medium.

# %%
# !bash scripts/colab_run_recommended.sh hadamard5_medium

# %% [markdown]
# Check status or pack outputs.

# %%
# !bash scripts/colab_status.sh configs/colab/hadamard5_medium_noise001_colab.yaml
# !bash scripts/colab_pack_outputs.sh configs/colab/hadamard5_medium_noise001_colab.yaml
